# %%
import zarr

# %%
from itkwidgets import view

# %%
z = zarr.open_array(
    "https://data-humerus.webknossos.org/data/zarr/scalable_minds/skin/color/4-4-1"
)

# %%
from zarr.storage import FSStore

fsstore = FSStore('https://dandiarchive.s3.amazonaws.com/zarr/7723d02f-1f71-4553-a7b0-47bda1ae8b42')
brainstem = zarr.open_group(fsstore, mode='r')

view(brainstem)
# Out:
#                 <img id="screenshot_imjoy_window_8317ae5a-7755-4a90-94c7-cf07c627bc17" src=data:image/png;base64,...>
#                 <script type="text/javascript">
#                     var image = document.getElementById("screenshot_imjoy_window_8317ae5a-7755-4a90-94c7-cf07c627bc17");
#                     image.src = "data:image/png;base64,...";
#                     var viewer = document.getElementById("imjoy_window_8317ae5a-7755-4a90-94c7-cf07c627bc17");
#                     // Hide the static image if the Viewer is visible
#                     image.style.display = viewer ? "none" : "block";
#                 </script>
# <div id="9fd7dafe-d1ac-422b-9fa9-0a425f19a1ca"></div>
